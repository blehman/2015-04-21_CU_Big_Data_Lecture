# %%
# Import libraries 
from nltk import *
import json
from pprint import *

# %%
# Get Data
with open('data/body_prac.txt', 'rb') as f:
    docs = f.readlines()
    
data = []
with open('data/geoData.json','rb') as f:
    counter = 0
    for line in f.readlines():
        #print line
        try: 
            x = json.loads(line)
            pprint(x)
            print
            print "-------------"
            print "-------------"
            print
        except ValueError:
            print "ERROR: {}".format(line)
            continue
        counter +=1
        if counter == 5:
            break
# Out:
# ERROR:
#
# {u'actor': {u'displayName': u'JAAAAA\u270c\ufe0f',
#             u'favoritesCount': 44,
#             u'followersCount': 1475,
#             u'friendsCount': 694,
#             u'id': u'id:twitter.com:339251466',
#             u'image': u'https://pbs.twimg.com/profile_images/576872919084699648/ZEIJqrf0_normal.jpeg',
#             u'languages': [u'en'],
#             u'link': u'http://www.twitter.com/TheLifeof_Ja',
#             u'links': [{u'href': None, u'rel': u'me'}],
#             u'listedCount': 10,
#             u'location': {u'displayName': u'Gaffney  USC ',
#                           u'objectType': u'place'},
#             u'objectType': u'person',
#             u'postedTime': u'2011-07-20T20:26:45.000Z',
#             u'preferredUsername': u'TheLifeof_Ja',
#             u'statusesCount': 146171,
#             u'summary': u"#RIPGrandmaP #RIPTalia\u2764\ufe0f University of South Carolina'16 Chemistry major Pre Med Student",
# ...

# %%
# Manipulate data 
for doc in docs:
    #print doc.strip()
    tokens1 = doc.lower().split(" ")
    print tokens1
    tokens2 = word_tokenize(doc.lower().decode('utf-8'))
    print tokens2
    print "-------------"
    print "-------------"
    
#for line in data:
#    #rec = json.loads(line)
#    pprint(line)
# Out:
# ['"if', 'you', 'have', 'no', 'eyebrows', 'nobody', 'will', 'know', 'your', 'mood', 'lmao"\n']
# [u'``', u'if', u'you', u'have', u'no', u'eyebrows', u'nobody', u'will', u'know', u'your', u'mood', u'lmao', u"''"]
# -------------
# -------------
# ['"oceandrivemag', 'wants', 'to', 'know:', 'who', 'is', 'the', 'most', 'inspiring,', 'awesome', 'and', 'influential', 'woman', 'in', 'your', 'life?\xe2\x80\xa6', 'https://t.co/slyji569v3"\n']
# [u'``', u'oceandrivemag', u'wants', u'to', u'know', u':', u'who', u'is', u'the', u'most', u'inspiring', u',', u'awesome', u'and', u'influential', u'woman', u'in', u'your', u'life', u'?', u'\u2026', u'https', u':', u'//t.co/slyji569v3', u"''"]
# -------------
# -------------
# ['"ha.', 'yes', "that's", 'so', 'true.', '#kingmason', '', 'https://t.co/iuklaazv9g"\n']
# [u'``', u'ha', u'.', u'yes', u'that', u"'s", u'so', u'true', u'.', u'#', u'kingmason', u'https', u':', u'//t.co/iuklaazv9g', u"''"]
# -------------
# -------------
# ...
